# %%
from pandas_datareader import Options

import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('white')
sns.set_context('paper')

# %matplotlib inline

# %%
aapl = Options('aapl', 'yahoo')

# %%
aapl.expiry_dates
# Out:
# [datetime.date(2017, 11, 24),
#  datetime.date(2017, 12, 1),
#  datetime.date(2017, 12, 8),
#  datetime.date(2017, 12, 15),
#  datetime.date(2017, 12, 22),
#  datetime.date(2017, 12, 29),
#  datetime.date(2018, 1, 5),
#  datetime.date(2018, 1, 19),
#  datetime.date(2018, 2, 16),
#  datetime.date(2018, 4, 20),
#  datetime.date(2018, 6, 15),
#  datetime.date(2018, 7, 20),
#  datetime.date(2018, 9, 21),
#  datetime.date(2019, 1, 18),
#  datetime.date(2020, 1, 17)]

# %%
data = aapl.get_all_data()

# %%
jan_options = data.loc[(slice(None), '2018-01-19', slice(None)),:]

# %%
jan_options[jan_options.Vol > 100]
# Out:
#                                               Last     Bid     Ask       Chg  \
# Strike Expiry     Type Symbol
# 2.5    2018-01-19 call AAPL180119C00002500  173.00  171.80  172.60  0.000000
# 25.0   2018-01-19 call AAPL180119C00025000  150.40  149.35  150.15  0.000000
# 35.0   2018-01-19 call AAPL180119C00035000  140.50  139.40  140.20  0.000000
# 70.0   2018-01-19 call AAPL180119C00070000  104.70  104.80  105.55  0.000000
#                   put  AAPL180119P00070000    0.01    0.00    0.01  0.000000
# 87.5   2018-01-19 call AAPL180119C00087500   85.50   87.35   88.05  0.000000
# 95.0   2018-01-19 put  AAPL180119P00095000    0.01    0.01    0.02  0.000000
# 100.0  2018-01-19 put  AAPL180119P00100000    0.01    0.00    0.01  0.000000
# 110.0  2018-01-19 call AAPL180119C00110000   65.60   65.05   65.70  0.599998
# 120.0  2018-01-19 put  AAPL180119P00120000    0.03    0.02    0.03  0.000000
# 130.0  2018-01-19 put  AAPL180119P00130000    0.06    0.05    0.07  0.000000
# 135.0  2018-01-19 put  AAPL180119P00135000    0.07    0.08    0.09 -0.040000
# 140.0  2018-01-19 call AAPL180119C00140000   35.75   35.30   35.75  0.750000
#                   put  AAPL180119P00140000    0.13    0.12    0.13 -0.010000
# 145.0  2018-01-19 put  AAPL180119P00145000    0.17    0.18    0.19 -0.030000
# 150.0  2018-01-19 call AAPL180119C00150000   25.60   25.60   25.80  0.050001
#                   put  AAPL180119P00150000    0.28    0.27    0.29 -0.050000
# 155.0  2018-01-19 put  AAPL180119P00155000    0.47    0.46    0.48 -0.040000
# 160.0  2018-01-19 call AAPL180119C00160000   16.25   16.20   16.35  0.049999
#                   put  AAPL180119P00160000    0.83    0.82    0.84 -0.060000
# 165.0  2018-01-19 call AAPL180119C00165000   11.92   11.90   12.00 -0.080000
#                   put  AAPL180119P00165000    1.50    1.48    1.51 -0.080000
# 170.0  2018-01-19 call AAPL180119C00170000    8.15    8.05    8.20 -0.070001
#                   put  AAPL180119P00170000    2.71    2.70    2.71 -0.090000
# 175.0  2018-01-19 call AAPL180119C00175000    5.10    5.10    5.15 -0.100000
#                   put  AAPL180119P00175000    4.63    4.60    4.70 -0.120000
# 180.0  2018-01-19 call AAPL180119C00180000    2.98    2.97    2.99 -0.100000
# 185.0  2018-01-19 call AAPL180119C00185000    1.68    1.66    1.70 -0.030000
# 190.0  2018-01-19 call AAPL180119C00190000    0.92    0.90    0.94 -0.010000
#
#                                                   IV  Root  IsNonstandard  \
# Strike Expiry     Type Symbol
# 2.5    2018-01-19 call AAPL180119C00002500  4.859379  AAPL          False
# 25.0   2018-01-19 call AAPL180119C00025000  2.125005  AAPL          False
# 35.0   2018-01-19 call AAPL180119C00035000  1.814454  AAPL          False
# 70.0   2018-01-19 call AAPL180119C00070000  1.041997  AAPL          False
#                   put  AAPL180119P00070000  0.718753  AAPL          False
# 87.5   2018-01-19 call AAPL180119C00087500  0.819338  AAPL          False
# 95.0   2018-01-19 put  AAPL180119P00095000  0.531255  AAPL          False
# 100.0  2018-01-19 put  AAPL180119P00100000  0.476568  AAPL          False
# 110.0  2018-01-19 call AAPL180119C00110000  0.626469  AAPL          False
# 120.0  2018-01-19 put  AAPL180119P00120000  0.367194  AAPL          False
# 130.0  2018-01-19 put  AAPL180119P00130000  0.326179  AAPL          False
# 135.0  2018-01-19 put  AAPL180119P00135000  0.298835  AAPL          False
# 140.0  2018-01-19 call AAPL180119C00140000  0.387946  AAPL          False
#                   put  AAPL180119P00140000  0.276374  AAPL          False
# 145.0  2018-01-19 put  AAPL180119P00145000  0.253914  AAPL          False
# 150.0  2018-01-19 call AAPL180119C00150000  0.295661  AAPL          False
#                   put  AAPL180119P00150000  0.232918  AAPL          False
# 155.0  2018-01-19 put  AAPL180119P00155000  0.214607  AAPL          False
# 160.0  2018-01-19 call AAPL180119C00160000  0.234444  AAPL          False
#                   put  AAPL180119P00160000  0.199227  AAPL          False
# 165.0  2018-01-19 call AAPL180119C00165000  0.211800  AAPL          False
#                   put  AAPL180119P00165000  0.186287  AAPL          False
# 170.0  2018-01-19 call AAPL180119C00170000  0.196785  AAPL          False
#                   put  AAPL180119P00170000  0.176278  AAPL          False
# 175.0  2018-01-19 call AAPL180119C00175000  0.187203  AAPL          False
#                   put  AAPL180119P00175000  0.169930  AAPL          False
# 180.0  2018-01-19 call AAPL180119C00180000  0.182869  AAPL          False
# 185.0  2018-01-19 call AAPL180119C00185000  0.185555  AAPL          False
# 190.0  2018-01-19 call AAPL180119C00190000  0.189705  AAPL          False
# 195.0  2018-01-19 call AAPL180119C00195000  0.197274  AAPL          False
# 200.0  2018-01-19 call AAPL180119C00200000  0.206063  AAPL          False
# 205.0  2018-01-19 put  AAPL180119P00205000  0.228523  AAPL          False
# 235.0  2018-01-19 call AAPL180119C00235000  0.253914  AAPL          False
# 245.0  2018-01-19 call AAPL180119C00245000  0.304694  AAPL          False
# 285.0  2018-01-19 call AAPL180119C00285000  0.398444  AAPL          False
#
#                                            Underlying  Underlying_Price  \
# Strike Expiry     Type Symbol
# 2.5    2018-01-19 call AAPL180119C00002500       AAPL            174.97
# 25.0   2018-01-19 call AAPL180119C00025000       AAPL            174.97
# 35.0   2018-01-19 call AAPL180119C00035000       AAPL            174.97
# 70.0   2018-01-19 call AAPL180119C00070000       AAPL            174.97
#                   put  AAPL180119P00070000       AAPL            174.97
# 87.5   2018-01-19 call AAPL180119C00087500       AAPL            174.97
# 95.0   2018-01-19 put  AAPL180119P00095000       AAPL            174.97
# 100.0  2018-01-19 put  AAPL180119P00100000       AAPL            174.97
# 110.0  2018-01-19 call AAPL180119C00110000       AAPL            174.97
# 120.0  2018-01-19 put  AAPL180119P00120000       AAPL            174.97
# 195.0  2018-01-19 call AAPL180119C00195000  {'contractSymbol': 'AAPL180119C00195000', 'str...
# 200.0  2018-01-19 call AAPL180119C00200000  {'contractSymbol': 'AAPL180119C00200000', 'str...
# 205.0  2018-01-19 put  AAPL180119P00205000  {'contractSymbol': 'AAPL180119P00205000', 'str...
# 235.0  2018-01-19 call AAPL180119C00235000  {'contractSymbol': 'AAPL180119C00235000', 'str...
# 245.0  2018-01-19 call AAPL180119C00245000  {'contractSymbol': 'AAPL180119C00245000', 'str...
# 285.0  2018-01-19 call AAPL180119C00285000  {'contractSymbol': 'AAPL180119C00285000', 'str...

# %%
jan_calls = jan_options.loc[(slice(None), slice(None), 'call'), :]
jan_puts = jan_options.loc[(slice(None), slice(None), 'put'), :]

plt.plot(jan_calls.index.get_level_values('Strike'),
    jan_calls.loc[(slice(None), slice(None), 'call'), :].Vol,
        label='Calls')
plt.plot(jan_puts.index.get_level_values('Strike'),
    jan_puts.loc[(slice(None), slice(None), 'put'), :].Vol,
        label='Puts')
plt.title('Volume Traded')
plt.xlim((100,220))
plt.ylim((0,6000))
plt.axvline(aapl.underlying_price, c='k', label='Spot')
plt.legend()

# %%
plt.figure(figsize=(3,4/1.618))

plt.plot(jan_calls.index.get_level_values('Strike'),
    jan_calls.loc[(slice(None), slice(None), 'call'), :].IV,
        label='Calls')
plt.plot(jan_puts.index.get_level_values('Strike'),
    jan_puts.loc[(slice(None), slice(None), 'put'), :].IV,
        label='Puts')
plt.title('AAPL Jan18 Implied Volatility')
plt.ylabel('Implied Volatility')
plt.xlabel('Strike Price')
plt.xlim((100,220))
plt.ylim((0,.8))
plt.axvline(aapl.underlying_price, c='k', label='Spot', linewidth=1)
sns.despine()
plt.legend()
plt.tight_layout()
plt.savefig('report/figs/aapliv.eps')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-3d07b6e90109> in <module>()
#      16 plt.legend()
#      17 plt.tight_layout()
# ---> 18 plt.savefig('report/figs/aapliv.eps')
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     695 def savefig(*args, **kwargs):
#     696     fig = gcf()
# --> 697     res = fig.savefig(*args, **kwargs)
#     698     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     699     return res
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py in savefig(self, fname, **kwargs)
#    1812             self.set_frameon(frameon)
#    1813
# -> 1814         self.canvas.print_figure(fname, **kwargs)
#    1815
#    1816         if frameon:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2257                 orientation=orientation,
#    2258                 bbox_inches_restore=_bbox_inches_restore,
# -> 2259                 **kwargs)
#    2260         finally:
#    2261             if bbox_inches and restore_bbox:
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_ps.py in print_eps(self, outfile, *args, **kwargs)
#     911
#     912     def print_eps(self, outfile, *args, **kwargs):
# --> 913         return self._print_ps(outfile, 'eps', *args, **kwargs)
#     914
#     915     def _print_ps(self, outfile, format, *args, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_ps.py in _print_ps(self, outfile, format, *args, **kwargs)
#     939             self._print_figure(outfile, format, imagedpi, facecolor, edgecolor,
#     940                                orientation, isLandscape, papertype,
# --> 941                                **kwargs)
#     942
#     943     def _print_figure(self, outfile, format, dpi=72, facecolor='w', edgecolor='w',
#
# ~/anaconda3/lib/python3.6/site-packages/matplotlib/backends/backend_ps.py in _print_figure(self, outfile, format, dpi, facecolor, edgecolor, orientation, isLandscape, papertype, metadata, **kwargs)
#    1190                 print_figure_impl(fh)
#    1191             else:
# -> 1192                 with io.open(outfile, 'w', encoding='latin-1') as fh:
#    1193                     print_figure_impl(fh)
#    1194
#
# FileNotFoundError: [Errno 2] No such file or directory: 'report/figs/aapliv.eps'
